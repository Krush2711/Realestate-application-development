# %%
import pandas as pd

# %%
flat = pd.read_csv('data_flats_cleaned.csv')
house = pd.read_csv('data_house_cleaned.csv')

# %%
flat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2996 entries, 0 to 2995
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   type             2996 non-null   object
#  2   society          2995 non-null   object
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     2996 non-null   object
#  7   bedRoom          2996 non-null   int64
#  8   bathroom         2996 non-null   int64
#  9   balcony          2996 non-null   int64
#  10  additionalRoom   1692 non-null   object
#  11  address          2990 non-null   object
#  12  floorNum         2994 non-null   float64
#  13  facing           2996 non-null   object
#  14  agePossession    2995 non-null   object
#  15  nearbyLocations  2905 non-null   object
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    958 non-null    object
#  1   type             958 non-null    object
#  2   society          391 non-null    object
#  3   price            958 non-null    float64
#  4   price_per_sqft   958 non-null    int64
#  5   area             958 non-null    float64
#  6   areaWithType     958 non-null    object
#  7   bedRoom          958 non-null    int64
#  8   bathroom         958 non-null    int64
#  9   balcony          958 non-null    int64
#  10  additionalRoom   577 non-null    object
#  11  address          953 non-null    object
#  12  floorNum         938 non-null    float64
#  13  facing           958 non-null    object
#  14  agePossession    958 non-null    object
#  15  nearbyLocations  843 non-null    object
# ...

# %%
df = pd.concat([flat, house], ignore_index=True)
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head(10)
# Out:
#                                  property_name   type  \
# 0              3 BHK Flat in Sector 65 Gurgaon   flat
# 1                    3 BHK Flat in Palam Vihar   flat
# 2              3 BHK Flat in Sector 90 Gurgaon   flat
# 3              2 BHK Flat in Sector 36 Gurgaon   flat
# 4              2 BHK Flat in Sector 85 Gurgaon   flat
# 5              3 BHK Flat in Sector 90 Gurgaon   flat
# 6              3 BHK Flat in Sector 77 Gurgaon   flat
# 7             2 BHK Flat in Sector 103 Gurgaon   flat
# 8                          2 BHK Flat in Sohna   flat
# 9  6 Bedroom House for sale in Uppals Southend  house
#
#                           society  price  price_per_sqft     area  \
# 0                  m3m golfestate   4.94         16233.0  3043.00
# 1     bestech park view residency   1.55          8072.0  1920.00
# 2               dlf regal gardens   1.25          8116.0  1540.00
# 3  signature global infinity mall   0.41          6269.0   654.00
# ...

# %%
df.to_csv('data_merged.csv', index=False)
