# %%
import pandas as pd 
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('data_flats.csv')

# %%
df.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                10
# area                 13
# areaWithType          9
# bedRoom               9
# bathroom              9
# balcony               9
# additionalRoom     1323
# address              15
# floorNum             11
# facing              890
# agePossession        10
# nearbyLocations     104
# description           9
# furnishDetails      814
# features            423
# rating              341
# property_id           9
# dtype: int64

# %%
df.drop(['link', 'rating', 'property_id'], axis =1 , inplace=True)

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#               area                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df.isnull().sum()
# Out:
# property_name         0
# society               1
# price                10
# area                 13
# areaWithType          9
# bedRoom               9
# bathroom              9
# balcony               9
# additionalRoom     1323
# address              15
# floorNum             11
# facing              890
# agePossession        10
# nearbyLocations     104
# description           9
# furnishDetails      814
# features            423
# dtype: int64

# %%
df = df.dropna(subset=['price'])

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.5 Crore           59
# 1.2 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 75 Lac              38
# 1.65 Crore          38
# 1.8 Crore           37
# 1.7 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 1.45 Crore          31
# 85 Lac              31
# 1.05 Crore          30
# 2.5 Crore           29
# 60 Lac              29
# 40 Lac              29
# 2.1 Crore           26
# 45 Lac              26
# 65 Lac              25
# 35 Lac              23
# 2.35 Crore          23
# 1.85 Crore          23
# 3 Crore             22
# 70 Lac              21
# 55 Lac              20
# 2.25 Crore          20
# ...

# %%
df.shape
# Out:
# (3007, 17)

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.5 Crore           59
# 1.2 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 75 Lac              38
# 1.65 Crore          38
# 1.8 Crore           37
# 1.7 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 1.45 Crore          31
# 85 Lac              31
# 1.05 Crore          30
# 2.5 Crore           29
# 60 Lac              29
# 40 Lac              29
# 2.1 Crore           26
# 45 Lac              26
# 65 Lac              25
# 35 Lac              23
# 2.35 Crore          23
# 1.85 Crore          23
# 3 Crore             22
# 70 Lac              21
# 55 Lac              20
# 2.25 Crore          20
# ...

# %%
df = df[df['price'] != "Price on Request"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3016
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   society          2995 non-null   object
#  2   price            2996 non-null   object
#  3   area             2996 non-null   object
#  4   areaWithType     2996 non-null   object
#  5   bedRoom          2996 non-null   object
#  6   bathroom         2996 non-null   object
#  7   balcony          2996 non-null   object
#  8   additionalRoom   1692 non-null   object
#  9   address          2990 non-null   object
#  10  floorNum         2994 non-null   object
#  11  facing           2122 non-null   object
#  12  agePossession    2995 non-null   object
#  13  nearbyLocations  2905 non-null   object
#  14  description      2996 non-null   object
#  15  furnishDetails   2200 non-null   object
#  16  features         2589 non-null   object
# ...

# %%
def treat_price(x):
    if type(x) == float:
        return x
    else:
        if x[1] == 'Lac':
            return round(float(x[0])/100,2)
        else:
            return round(float(x[0]),2)

# %%
df['price']  =df['price'].str.split(' ').apply(treat_price)

# %%
df['area'].value_counts()
# Out:
# area
# ₹ 10,000/sq.ft.     19
# ₹ 8,000/sq.ft.      16
# ₹ 12,500/sq.ft.     16
# ₹ 6,666/sq.ft.      13
# ₹ 5,000/sq.ft.      13
# ₹ 7,500/sq.ft.      12
# ₹ 8,333/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 12,000/sq.ft.      8
# ₹ 7,000/sq.ft.       8
# ₹ 9,000/sq.ft.       7
# ₹ 11,111/sq.ft.      6
# ₹ 5,500/sq.ft.       6
# ₹ 6,578/sq.ft.       6
# ₹ 8,928/sq.ft.       6
# ₹ 9,230/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 16,000/sq.ft.      5
# ₹ 6,500/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 8,888/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 8,571/sq.ft.       5
# ₹ 7,142/sq.ft.       5
# ₹ 5,556/sq.ft.       5
# ₹ 7,692/sq.ft.       5
# ₹ 4,444/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 5,600/sq.ft.       5
# ₹ 11,428/sq.ft.      5
# ₹ 4,615/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 5,384/sq.ft.       5
# ₹ 7,641/sq.ft.       5
# ₹ 4,666/sq.ft.       5
# ₹ 9,822/sq.ft.       4
# ₹ 8,432/sq.ft.       4
# ₹ 4,500/sq.ft.       4
# ...

# %%
str = "₹ 6,224/sq.ft."
str.split('/')[0].replace(',', "").replace('₹', '').strip()
# Out:
# '6224'

# %%
df['area'] = df['area'].str.split('/').str.get(0).str.replace(",", '').str.replace("₹", "").str.strip().astype(float)

# %%
df.rename(columns={'area':'price_per_sqft'},inplace=True)
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3016
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   society          2995 non-null   object
#  2   price            2996 non-null   float64
#  3   price_per_sqft   2996 non-null   float64
#  4   areaWithType     2996 non-null   object
#  5   bedRoom          2996 non-null   object
#  6   bathroom         2996 non-null   object
#  7   balcony          2996 non-null   object
#  8   additionalRoom   1692 non-null   object
#  9   address          2990 non-null   object
#  10  floorNum         2994 non-null   object
#  11  facing           2122 non-null   object
#  12  agePossession    2995 non-null   object
#  13  nearbyLocations  2905 non-null   object
#  14  description      2996 non-null   object
#  15  furnishDetails   2200 non-null   object
# ...

# %%
df['balcony'].isnull().sum()
# Out:
# 0

# %%
df['bedRoom'] = df['bedRoom'].str.split(' ').str.get(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3016
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   society          2995 non-null   object
#  2   price            2996 non-null   float64
#  3   price_per_sqft   2996 non-null   float64
#  4   areaWithType     2996 non-null   object
#  5   bedRoom          2996 non-null   int32
#  6   bathroom         2996 non-null   object
#  7   balcony          2996 non-null   object
#  8   additionalRoom   1692 non-null   object
#  9   address          2990 non-null   object
#  10  floorNum         2994 non-null   object
#  11  facing           2122 non-null   object
#  12  agePossession    2995 non-null   object
#  13  nearbyLocations  2905 non-null   object
#  14  description      2996 non-null   object
#  15  furnishDetails   2200 non-null   object
#  16  features         2589 non-null   object
# ...

# %%
df['balcony'] =  df['balcony'].str.split(' ').str.get(0).str.replace('+', '').str.replace('No', '0').astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3016
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   society          2995 non-null   object
#  2   price            2996 non-null   float64
#  3   price_per_sqft   2996 non-null   float64
#  4   areaWithType     2996 non-null   object
#  5   bedRoom          2996 non-null   int32
#  6   bathroom         2996 non-null   object
#  7   balcony          2996 non-null   Int16
#  8   additionalRoom   1692 non-null   object
#  9   address          2990 non-null   object
#  10  floorNum         2994 non-null   object
#  11  facing           2122 non-null   object
#  12  agePossession    2995 non-null   object
#  13  nearbyLocations  2905 non-null   object
#  14  description      2996 non-null   object
#  15  furnishDetails   2200 non-null   object
#  16  features         2589 non-null   object
# ...

# %%
df['bathroom'] = df['bathroom'].str.split(' ').str.get(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3016
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   society          2995 non-null   object
#  2   price            2996 non-null   float64
#  3   price_per_sqft   2996 non-null   float64
#  4   areaWithType     2996 non-null   object
#  5   bedRoom          2996 non-null   int32
#  6   bathroom         2996 non-null   int32
#  7   balcony          2996 non-null   Int16
#  8   additionalRoom   1692 non-null   object
#  9   address          2990 non-null   object
#  10  floorNum         2994 non-null   object
#  11  facing           2122 non-null   object
#  12  agePossession    2995 non-null   object
#  13  nearbyLocations  2905 non-null   object
#  14  description      2996 non-null   object
#  15  furnishDetails   2200 non-null   object
#  16  features         2589 non-null   object
# ...

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)        2         2
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)        2         2
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)        2         2
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)        2         2
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)        2         2
#
#    balcony additionalRoom                              address  \
# ...

# %%
import re

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).str.replace('Ground', '0').str.replace('Basement', '0').str.replace('Lower', '0').str.extract(r'(\d+)')

# %%
df['society'] = (
    df['society']
    .str.replace(r'\d+(\.\d+)?\s?★', '', regex=True)
    .str.strip()
    .str.lower())
df['society'].value_counts().shape
# Out:
# (598,)

# %%
df['facing'].value_counts()
# Out:
# facing
# DK            874
# North-East    505
# East          489
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# 0

# %%
df['facing'].fillna('DK', inplace=True)

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            apna enclave   0.50
# 2              2 BHK Flat in Sohna  tulsiani easy in homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     smart world orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        parkwood westend   0.70
#
#    price_per_sqft    area                            areaWithType  bedRoom  \
# 0          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)        2
# 1          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)        2
# 2          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)        2
# 3         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)        2
# 4          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)        2
#
#    bathroom  balcony additionalRoom                              address  \
# ...

# %%
df.insert(loc=1, column='type', value='flat')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 3016
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2996 non-null   object
#  1   type             2996 non-null   object
#  2   society          2995 non-null   object
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     2996 non-null   object
#  7   bedRoom          2996 non-null   int32
#  8   bathroom         2996 non-null   int32
#  9   balcony          2996 non-null   Int16
#  10  additionalRoom   1692 non-null   object
#  11  address          2990 non-null   object
#  12  floorNum         2994 non-null   object
#  13  facing           2996 non-null   object
#  14  agePossession    2995 non-null   object
#  15  nearbyLocations  2905 non-null   object
#  16  description      2996 non-null   object
# ...
